# %% [markdown]
# <h2>Text to Gesture Conversion</h2>

# %% [markdown]
# <h3>Code</h3>

# %%
from PIL import Image
import os
import matplotlib.pyplot as plt
while(1):
    try:
            letter=input('Enter alphabet: ')
            char=letter
            if letter.islower():
                char=letter.upper()
            
            file_path="Gesture_Images/"+char+".jpg"
            
            if os.path.exists(file_path):
                print("File Path: ", file_path)
                im = Image.open(file_path) 
                plt.imshow(im)
                plt.show()
             
    except KeyboardInterrupt:
        break
# Out:
# Enter alphabet: H
# File Path:  Gesture_Images/H.jpg
# Enter alphabet: g
# File Path:  Gesture_Images/G.jpg
# Enter alphabet: A
# File Path:  Gesture_Images/A.jpg
# Enter alphabet: M
# Enter alphabet: 123
